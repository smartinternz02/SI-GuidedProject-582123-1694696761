# %%
#Sarvesh Ashish
import pandas as pd
import seaborn as sb

# %%
df=pd.read_csv('C:/Users/Sarvesh/Downloads/penguins_size.csv')

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
sb.distplot(df.culmen_length_mm)
# Out:
# c:\Users\Sarvesh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='Density'>

# %%
sb.displot(df.body_mass_g	)

# %%
sb.lineplot(x=df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sb.scatterplot(x=df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sb.pairplot(df)

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
rt=df.describe()
rt
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['culmen_length_mm']=df['culmen_length_mm'].fillna(df['culmen_length_mm'].median())

# %%
df['culmen_depth_mm']=df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median())

# %%
df['flipper_length_mm']=df['flipper_length_mm'].fillna(df['flipper_length_mm'].median())

# %%
df['body_mass_g']=df['body_mass_g'].fillna(df['body_mass_g'].median())

# %%
df['sex'].mode()
# Out:
# 0    MALE
# dtype: object

# %%
df.sex= df.sex.fillna(df.sex.mode().iloc[0])

# %%
df.sex= df.sex.fillna(df.sex.mode())

# %%
df.species.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object>

# %%
df.species.nunique()
# Out:
# 3

# %%
sb.boxplot(df['culmen_length_mm'])
# Out:
# c:\Users\Sarvesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='culmen_length_mm'>

# %%
sb.boxplot(df['culmen_depth_mm'])
# Out:
# c:\Users\Sarvesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='culmen_depth_mm'>

# %%
sb.boxplot(df['flipper_length_mm'])
# Out:
# c:\Users\Sarvesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='flipper_length_mm'>

# %%
sb.boxplot(df['body_mass_g'])
# Out:
# c:\Users\Sarvesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body_mass_g'>

# %%
df.corr()
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235000           0.655858
# culmen_depth_mm           -0.235000         1.000000          -0.583832
# flipper_length_mm          0.655858        -0.583832           1.000000
# body_mass_g                0.594925        -0.471942           0.871221
#
#                    body_mass_g
# culmen_length_mm      0.594925
# culmen_depth_mm      -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['species']=le.fit_transform(df['species'])
df['sex']=le.fit_transform(df['sex'])
df['island']=le.fit_transform(df['island'])

# %%
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2             39.10             18.7              181.0
# 1          0       2             39.50             17.4              186.0
# 2          0       2             40.30             18.0              195.0
# 3          0       2             44.45             17.3              197.0
# 4          0       2             36.70             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0             44.45             17.3              197.0
# 340        2       0             46.80             14.3              215.0
# 341        2       0             50.40             15.7              222.0
# 342        2       0             45.20             14.8              212.0
# 343        2       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(columns='species')

# %%
y=df['species']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3       4050.0    2
# 4       3450.0    1

# %%
x_scale=pd.DataFrame(scale.fit_transform(x),columns=x.columns)

# %%
x_scale
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0       1.0          0.254545         0.666667           0.152542
# 1       1.0          0.269091         0.511905           0.237288
# 2       1.0          0.298182         0.583333           0.389831
# 3       1.0          0.449091         0.500000           0.423729
# 4       1.0          0.167273         0.738095           0.355932
# ..      ...               ...              ...                ...
# 339     0.0          0.449091         0.500000           0.423729
# 340     0.0          0.534545         0.142857           0.728814
# 341     0.0          0.665455         0.309524           0.847458
# 342     0.0          0.476364         0.202381           0.677966
# 343     0.0          0.647273         0.357143           0.694915
#
#      body_mass_g  sex
# 0       0.291667  1.0
# 1       0.305556  0.5
# 2       0.152778  0.5
# 3       0.375000  1.0
# 4       0.208333  0.5
# ..           ...  ...
# ...

# %%
x_scale=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x_scale.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.5
# 2  0.5
# 3  1.0
# 4  0.5

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scale,y,test_size=0.3,random_state=0)

# %%
x_train.shape
# Out:
# (240, 6)

# %%
x_test.shape
# Out:
# (104, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (104,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Y_PRED=model.predict(x_test)
Y_PRED
# Out:
# array([ 0.27594388,  0.12124024,  0.22390982,  2.05300841, -0.0672964 ,
#         1.86816824,  0.22310539,  1.21402984,  1.82163784,  0.18573011,
#         0.32601175,  1.80986763,  0.13777275,  1.83615419,  1.88495022,
#         0.3020488 ,  0.18133554,  1.76508278,  0.42146942,  0.02686026,
#         1.73308344,  0.14469832,  0.89254152,  0.09298234,  2.0148283 ,
#         2.22835047,  1.62219937,  0.10066309,  0.27934474,  1.64010867,
#         1.90386779,  0.78916574,  0.03254908,  0.28344455, -0.12789481,
#         0.96374021,  1.97537729,  0.83481911, -0.01606567,  0.44175613,
#        -0.08002308,  0.38954794,  0.06527787,  1.89042678,  1.8027002 ,
#        -0.0311631 ,  2.02952016,  1.21560823,  0.1027509 ,  2.0371613 ,
#         0.01663791,  0.16293144,  0.16156583,  0.47189331,  0.01005564,
#         0.71484379,  0.11947874,  2.17155212,  0.91553586,  1.99342442,
#         0.97799828,  1.03288025,  0.56098122,  1.64240421,  1.6957338 ,
# ...

# %%
#Sarvesh Ashish
